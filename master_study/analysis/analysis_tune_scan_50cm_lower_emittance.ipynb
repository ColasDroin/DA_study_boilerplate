# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %%
# Define study
STUDY_NAME = "tunescan_50cm_lower_emittance"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0016/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
# Replace nan with 20
df_to_plot.loc[60.311, 62.305] = 20

# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.5,
    bety=0.5,
    Nb = True,
    green_contour = 2,
    extended_diagonal=False,
    vmin = 4,
    vmax = 20.,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)

# %%
df
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.309      base_collider                            19.750
#              60.310      base_collider                            19.625
#              60.312      base_collider                            19.375
#              60.313      base_collider                            19.000
#              60.314      base_collider                            19.000
# ...                                ...                               ...
#       62.323 60.328      base_collider                             5.875
#              60.329      base_collider                             5.250
#       62.324 60.328      base_collider                             6.000
#              60.329      base_collider                             4.000
#       62.325 60.329      base_collider                             4.125
#
#                          qx      qy   dqx   dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.309  62.305  60.309  10.0  10.0       480.0      1363.0
#              60.310  62.305  60.310  10.0  10.0       480.0      1363.0
#              60.312  62.305  60.312  10.0  10.0       480.0      1363.0
#              60.313  62.305  60.313  10.0  10.0       480.0      1363.0
#              60.314  62.305  60.314  10.0  10.0       480.0      1363.0
# ...                     ...     ...   ...   ...         ...         ...
#       62.323 60.328  62.323  60.328  10.0  10.0       480.0      1363.0
#              60.329  62.323  60.329  10.0  10.0       480.0      1363.0
#       62.324 60.328  62.324  60.328  10.0  10.0       480.0      1363.0
#              60.329  62.324  60.329  10.0  10.0       480.0      1363.0
#       62.325 60.329  62.325  60.329  10.0  10.0       480.0      1363.0
#
#                      num_particles_per_bunch  crossing_angle
# beam  qx     qy
# lhcb1 62.305 60.309              180000000.0           170.0
#              60.310              180000000.0           170.0
#              60.312              180000000.0           170.0
#              60.313              180000000.0           170.0
#              60.314              180000000.0           170.0
# ...                                      ...             ...
#       62.323 60.328              180000000.0           170.0
#              60.329              180000000.0           170.0
#       62.324 60.328              180000000.0           170.0
#              60.329              180000000.0           170.0
#       62.325 60.329              180000000.0           170.0
#
# [230 rows x 10 columns]

# %%
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.309  19.750     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310  19.625  19.500     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311     NaN  19.750  19.625     NaN     NaN     NaN     NaN     NaN
# 60.312  19.375  19.375  19.375  19.375     NaN     NaN     NaN     NaN
# 60.313  19.000  19.125  19.250  19.375  19.000     NaN     NaN     NaN
# 60.314  19.000  18.375  19.125  18.875  18.875  18.625     NaN     NaN
# 60.315  17.625  18.250  18.250  18.000  18.250  18.250  18.250     NaN
# 60.316  17.250  17.250  17.250  17.625  17.625  17.750  17.875  17.625
# 60.317  16.750  16.875  16.750  16.750  16.625  16.500  16.750  16.875
# 60.318  16.875  16.500  16.000  15.875  16.125  16.375  16.125  16.125
# 60.319  16.000  15.875  15.875  16.125  15.625  15.875  15.625  15.500
# 60.320  14.375  14.750  15.250  15.125  15.125  14.875  14.875  14.750
# 60.321  13.375  13.500  13.750  13.625  13.500  13.875  14.375  13.625
# 60.322  12.625  12.500  12.250  12.500  12.750  12.625  12.500  13.000
# 60.323  11.375  10.625  11.250  11.500  11.500  11.375  11.750  11.500
# 60.324  10.125   9.875  10.000  10.125  10.500  10.625  10.625  10.375
# 60.325   9.875  10.000   9.125   9.125   9.000   9.250   9.375   9.500
# 60.326  10.250   9.375  10.000   9.750   9.000   9.125   8.625   8.125
# 60.327  10.000  10.000   9.500   9.000   8.875   9.250   9.000   9.250
# 60.328   9.000   8.875   8.750   8.625   8.625   8.500   7.875   7.250
# 60.329   6.875   7.125   6.625   6.625   7.000   6.500   6.250   7.000
#
# qx      62.313  62.314  ...  62.316  62.317  62.318  62.319  62.320  62.321  \
# qy                      ...
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317  17.375     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.318  16.250  16.250  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.319  15.375  15.375  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.320  14.375  14.625  ...  14.750     NaN     NaN     NaN     NaN     NaN
# 60.321  13.500  13.875  ...  13.750  13.875     NaN     NaN     NaN     NaN
# 60.322  13.125  13.000  ...  12.875  13.000  12.875     NaN     NaN     NaN
# 60.323  11.500  11.750  ...  11.750  11.625  11.875   12.00     NaN     NaN
# 60.324  10.500  10.375  ...  10.500  10.250  10.875   10.75  10.875     NaN
# 60.325  10.000   9.500  ...   9.375   9.250   9.500    9.50   9.750   9.750
# 60.326   8.875   8.375  ...   8.750   8.250   8.250    8.75   8.625   8.500
# 60.327   8.375   8.375  ...   7.875   7.625   7.250    7.50   7.500   7.250
# 60.328   7.875   8.125  ...   8.000   7.250   7.125    7.00   6.750   6.750
# 60.329   6.250   6.250  ...   6.000   6.375   6.000    5.75   5.750   5.375
#
# qx      62.322  62.323  62.324  62.325
# qy
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     NaN     NaN     NaN     NaN
# 60.324     NaN     NaN     NaN     NaN
# 60.325     NaN     NaN     NaN     NaN
# 60.326   8.375     NaN     NaN     NaN
# 60.327   7.375   7.625     NaN     NaN
# 60.328   6.000   5.875     6.0     NaN
# 60.329   4.875   5.250     4.0   4.125
#
# [21 rows x 21 columns]
