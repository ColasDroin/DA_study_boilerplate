# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %%
# Define study
STUDY_NAME = "tunescan_50cm_control_sofia"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0016/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.5,
    bety=0.5,
    Nb = True,
    green_contour = 2,
    extended_diagonal=False,
    vmin = 4,
    vmax = 20.,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 27
#      25 conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
#      26 conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
# ---> 27 analysis_functions.plot_heatmap(
#      28     df_to_plot,
#      29     STUDY_NAME + '_' + COLLIDER,
#      30     link=None,
#      31     plot_contours=True,
#      32     conf_mad=conf_mad,
#      33     conf_collider=conf_collider,
#      34     type_crossing="flatvh",
#      35     betx=0.5,
#      36     bety=0.5,
#      37     Nb = True,
#      38     green_contour = 2,
#      39     extended_diagonal=False,
#      40     vmin = 4,
#      41     vmax = 20.,
#      42 )
#      43 if SAVE_STUDY_EOS:
#      44     path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study_runIII_ions/master_study/analysis/analysis_functions.py:348, in plot_heatmap(df_to_plot, study_name, link, plot_contours, green_contour, conf_mad, conf_collider, type_crossing, betx, bety, Nb, levelling, CC, extended_diagonal, vmin, vmax)
#     346 data_smoothed[np.isnan(data_array)] = 0.0
#     347 if not extended_diagonal:
# --> 348     data_smoothed = data_smoothed + data_smoothed.T - np.diag(data_array.diagonal())
#     349 else:
#     350     # sum the upper and lower triangle, but not the intersection of the two matrices
#     351     intersection = np.zeros_like(data_smoothed)
#
# ValueError: operands could not be broadcast together with shapes (17,21) (21,17)
