# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %% [markdown]
# ### Collider new RP, 0.3/0.3

# %%
# Define study
STUDY_NAME = "tune_scan_new_RT"
COLLIDER = "base_collider"
PARQUET_PATH = f"../../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0016/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.3,
    bety=0.3,
    Nb = True,
    green_contour = 5.5,
    extended_diagonal=True,
    vmin = 4.5,
    vmax = 7.,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)

# %%
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.305   4.500   4.500   4.500   4.500     NaN     NaN     NaN     NaN
# 60.306   4.500   4.500   4.500   4.500   4.562     NaN     NaN     NaN
# 60.307   4.500   4.500   4.500   4.594   5.125   5.188     NaN     NaN
# 60.308   4.500   4.500   4.594   4.719   5.031   5.219   5.156     NaN
# 60.309   4.500   4.562   4.531   5.188   5.094   5.125   5.156   5.250
# 60.310   4.500   4.594   5.219   5.281   5.219   5.281   4.812   5.375
# 60.311   4.562   4.844   5.094   5.094   5.500   5.531   5.219   5.125
# 60.312   4.531   5.125   5.125   5.188   5.156   5.156   5.406   4.844
# 60.313   4.531   4.844   5.031   5.000   5.281   4.938   5.281   5.281
# 60.314   4.719   5.312   5.094   5.062   5.281   4.969   4.844   5.094
# 60.315   5.000   5.250   5.219   5.094   4.969   5.188   5.000   5.000
# 60.316   4.531   5.125   5.219   5.156   5.062   5.188   5.000   4.844
# 60.317   4.719   5.094   5.062   5.000   5.000   5.125   4.969   5.250
# 60.318   4.781   5.125   5.031   5.094   4.781   4.750   4.719   5.594
# 60.319   5.000   4.844   5.062   4.875   4.719   4.875   4.812   5.562
# 60.320   4.531   4.688   4.812   4.656   4.938   4.875   4.719   4.906
# 60.321   4.500   4.500   4.531   4.594   4.781   4.656   4.625   4.750
# 60.322   4.500   4.500   4.500   4.500   4.531   4.500   4.500   4.562
# 60.323   4.500   4.500   4.500   4.500   4.500   4.500   4.500   4.500
# 60.324   4.500   4.500   4.500   4.500   4.500   4.500   4.500   4.500
# 60.325   4.500   4.500   4.500   4.500   4.500   4.500   4.500   4.500
# 60.326   4.500   4.500   4.500   4.500   4.500   4.500   4.500   4.500
# 60.327   4.500   4.500   4.500   4.500   4.500   4.500   4.500   4.500
# 60.328   4.500   4.500   4.500   4.500   4.500   4.500   4.500   4.500
# 60.329   4.500   4.500   4.500   4.500   4.500   4.500   4.500   4.500
#
# qx      62.313  62.314  ...  62.320  62.321  62.322  62.323  62.324  62.325  \
# qy                      ...
# 60.305     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310   5.250     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311   5.219   5.156  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312   5.156   5.312  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313   5.188   5.250  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314   5.094   5.000  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315   5.344   6.000  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316   5.531   5.812  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317   5.969   6.250  ...   4.531     NaN     NaN     NaN     NaN     NaN
# 60.318   5.812   6.281  ...   4.656   4.500     NaN     NaN     NaN     NaN
# 60.319   5.500   5.844  ...   4.844   4.531     4.5     NaN     NaN     NaN
# 60.320   5.375   5.438  ...   4.969   4.531     4.5     4.5     NaN     NaN
# 60.321   5.219   4.812  ...   4.938   4.625     4.5     4.5     4.5     NaN
# 60.322   4.562   4.719  ...   4.781   4.656     4.5     4.5     4.5     4.5
# 60.323   4.500   4.500  ...   4.531   4.750     4.5     4.5     4.5     4.5
# 60.324   4.500   4.500  ...   4.500   4.500     4.5     4.5     4.5     4.5
# 60.325   4.500   4.500  ...   4.500   4.500     4.5     4.5     4.5     4.5
# 60.326   4.500   4.500  ...   4.500   4.500     4.5     4.5     4.5     4.5
# 60.327   4.500   4.500  ...   4.500   4.500     4.5     4.5     4.5     4.5
# 60.328   4.500   4.500  ...   4.500   4.500     4.5     4.5     4.5     4.5
# 60.329   4.500   4.500  ...   4.500   4.500     4.5     4.5     4.5     4.5
#
# qx      62.326  62.327  62.328  62.329
# qy
# 60.305     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     4.5     NaN     NaN     NaN
# 60.324     4.5     4.5     NaN     NaN
# 60.325     4.5     4.5     4.5     NaN
# 60.326     4.5     4.5     4.5     4.5
# 60.327     4.5     4.5     4.5     4.5
# 60.328     4.5     4.5     4.5     4.5
# 60.329     4.5     4.5     4.5     4.5
#
# [25 rows x 25 columns]
