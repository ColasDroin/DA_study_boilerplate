# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# # change directory to 'master_study/analysis'
# os.chdir('master_study/analysis')

# Local imports
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %%
# Define study
STUDY_NAME = "tunescan_50cm_2024_agressive"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0223/config_final.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.306      base_collider                            12.875
#              60.308      base_collider                            10.938
#              60.309      base_collider                            14.500
#              60.310      base_collider                            10.438
#              60.312      base_collider                            14.812
# ...                                ...                               ...
#       62.328 60.327      base_collider                             4.000
#              60.329      base_collider                             4.000
#       62.329 60.326      base_collider                             4.000
#              60.327      base_collider                             4.000
#              60.328      base_collider                             4.000
#
#                          qx      qy   dqx   dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.306  62.305  60.306  10.0  10.0         NaN         NaN
#              60.308  62.305  60.308  10.0  10.0         NaN         NaN
#              60.309  62.305  60.309  10.0  10.0         NaN         NaN
#              60.310  62.305  60.310  10.0  10.0         NaN         NaN
#              60.312  62.305  60.312  10.0  10.0         NaN         NaN
# ...                     ...     ...   ...   ...         ...         ...
#       62.328 60.327  62.328  60.327  10.0  10.0         NaN         NaN
#              60.329  62.328  60.329  10.0  10.0         NaN         NaN
#       62.329 60.326  62.329  60.326  10.0  10.0         NaN         NaN
#              60.327  62.329  60.327  10.0  10.0         NaN         NaN
#              60.328  62.329  60.328  10.0  10.0         NaN         NaN
#
#                      i_oct_b1  i_oct_b2  num_particles_per_bunch  \
# beam  qx     qy
# lhcb1 62.305 60.306     100.0     100.0              180000000.0
#              60.308     100.0     100.0              180000000.0
#              60.309     100.0     100.0              180000000.0
#              60.310     100.0     100.0              180000000.0
#              60.312     100.0     100.0              180000000.0
# ...                       ...       ...                      ...
#       62.328 60.327     100.0     100.0              180000000.0
#              60.329     100.0     100.0              180000000.0
#       62.329 60.326     100.0     100.0              180000000.0
#              60.327     100.0     100.0              180000000.0
#              60.328     100.0     100.0              180000000.0
#
#                      crossing_angle
# beam  qx     qy
# lhcb1 62.305 60.306           150.0
#              60.308           150.0
#              60.309           150.0
#              60.310           150.0
#              60.312           150.0
# ...                             ...
#       62.328 60.327           150.0
#              60.329           150.0
#       62.329 60.326           150.0
#              60.327           150.0
#              60.328           150.0
#
# [356 rows x 12 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.305     NaN  12.312  12.688  12.375     NaN     NaN     NaN     NaN
# 60.306  12.875     NaN  11.500  10.562  10.812     NaN     NaN     NaN
# 60.307     NaN  11.312     NaN  12.188  11.875  12.875     NaN     NaN
# 60.308  10.938     NaN  12.375     NaN  12.250  12.688  12.688     NaN
# 60.309  14.500     NaN  14.688     NaN     NaN  13.500  13.000  13.750
# 60.310  10.438     NaN  16.188  12.625  14.375     NaN  12.750  12.875
# 60.311     NaN  11.875  12.375  11.938  11.875  12.750     NaN  12.688
# 60.312  14.812  14.000  11.375  11.562  11.375     NaN  14.125     NaN
# 60.313  12.250  15.000  12.062  13.438  11.688  13.500  14.625     NaN
# 60.314  12.188  12.250  11.062  14.938  11.938  14.375  14.125  12.938
# 60.315  11.375  10.875  13.938  14.500     NaN  13.000  12.000  12.438
# 60.316  12.188  10.938  11.500  12.375  11.000  10.750  11.875  14.375
# 60.317  11.688  11.875  10.625  10.875  12.312  13.438  12.062  12.062
# 60.318  10.625  10.688  10.938  11.438  13.125  11.438  11.812  11.938
# 60.319  10.688  10.938  10.062   9.812  10.750  11.000  10.812  10.375
# 60.320   9.500   9.312  10.125  11.000  10.188  10.625  10.375  10.562
# 60.321   8.500  10.125  10.750  10.250   9.188   9.875  10.875  10.438
# 60.322   8.250   8.875   9.812   9.750   9.875   9.000   9.312   9.688
# 60.323   7.938   7.688   9.312   8.500   8.312   9.375   8.250   9.438
# 60.324   8.188   7.875   7.875   7.812   7.812   8.000   8.312   7.938
# 60.325   7.000   7.500   7.125   6.938   7.312   7.188   7.562   7.812
# 60.326   7.500   7.188   7.125   7.000   7.062   7.562   6.500   6.438
# 60.327   7.625   7.250   7.250   7.062   7.062   7.062   7.312   6.750
# 60.328   7.188   7.625   6.625   6.875   6.812   6.375   6.688   6.688
# 60.329   6.000   6.188   6.500   6.438   5.875   6.375   6.250   5.625
#
# qx      62.313  62.314  ...  62.320  62.321  62.322  62.323  62.324  62.325  \
# qy                      ...
# 60.305     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310  14.062     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311  13.062  13.625  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312  12.750  13.500  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN  13.250  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314  12.500     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315  13.312  13.125  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316  12.750  13.375  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317  12.188  12.125  ...  11.188     NaN     NaN     NaN     NaN     NaN
# 60.318  12.625  12.750  ...  11.312  10.438     NaN     NaN     NaN     NaN
# 60.319  11.688  11.125  ...  12.125  10.812   9.750     NaN     NaN     NaN
# 60.320  11.062  11.188  ...     NaN  11.438  10.062   8.750     NaN     NaN
# 60.321  10.562  10.625  ...  11.562     NaN  10.688   9.188   7.812     NaN
# 60.322  10.375   9.750  ...  10.750  10.812     NaN  10.000   7.938   6.875
# 60.323   8.375   8.750  ...   9.750   9.875  10.125     NaN   8.875   7.062
# 60.324   8.000   7.875  ...   8.688   8.688   9.062   9.250     NaN   7.750
# 60.325   7.500   7.375  ...   7.438   7.500   7.938   7.938   8.062     NaN
# 60.326   7.125   6.562  ...   7.062   6.938   6.812   6.750   6.562   6.938
# 60.327   7.062   6.312  ...   5.875   6.062   5.812   5.875   5.562   5.625
# 60.328   6.500   6.625  ...   5.500   5.438   4.938   4.875   4.812   4.375
# 60.329   6.000   5.562  ...   5.125   5.312   4.562   4.000   4.000   4.000
#
# qx      62.326  62.327  62.328  62.329
# qy
# 60.305     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323   6.000     NaN     NaN     NaN
# 60.324   6.188   4.688     NaN     NaN
# 60.325   6.188   4.812     4.0     NaN
# 60.326     NaN   4.375     4.0     4.0
# 60.327   5.500     NaN     4.0     4.0
# 60.328   4.438   4.000     NaN     4.0
# 60.329   4.000   4.000     4.0     NaN
#
# [25 rows x 25 columns]

# %%
# Interpolate to fill internal missing values (do not extrapolate)
df_to_plot = df_to_plot.interpolate(method='slinear', limit = 1)

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.5,
    bety=0.5,
    Nb = True,
    green_contour = 2,
    extended_diagonal=True,
    #small_ext_diagonal=True,
    vmin = 4,
    vmax = 15.,
    smooth_symmetry = True,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)
