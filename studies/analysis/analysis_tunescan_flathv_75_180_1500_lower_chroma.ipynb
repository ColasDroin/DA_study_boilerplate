# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
import analysis_functions

# Apply better style
analysis_functions.apply_heatmap_style()

# %% [markdown]
# ### Plot tune scan

# %%
# Define study
STUDY_NAME = "tunescan_flathv_75_180_1500_lower_chroma"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0016/config_final.yaml"

# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.309      base_collider                             3.862
#              60.310      base_collider                             4.207
#              60.311      base_collider                             4.207
#              60.312      base_collider                             3.931
#              60.313      base_collider                             4.690
# ...                                ...                               ...
#       62.323 60.328      base_collider                             4.621
#              60.329      base_collider                             4.138
#       62.324 60.328      base_collider                             4.483
#              60.329      base_collider                             4.000
#       62.325 60.329      base_collider                             4.069
#
#                          qx      qy  dqx  dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.309  62.305  60.309  5.0  5.0         NaN         NaN
#              60.310  62.305  60.310  5.0  5.0         NaN         NaN
#              60.311  62.305  60.311  5.0  5.0         NaN         NaN
#              60.312  62.305  60.312  5.0  5.0         NaN         NaN
#              60.313  62.305  60.313  5.0  5.0         NaN         NaN
# ...                     ...     ...  ...  ...         ...         ...
#       62.323 60.328  62.323  60.328  5.0  5.0         NaN         NaN
#              60.329  62.323  60.329  5.0  5.0         NaN         NaN
#       62.324 60.328  62.324  60.328  5.0  5.0         NaN         NaN
#              60.329  62.324  60.329  5.0  5.0         NaN         NaN
#       62.325 60.329  62.325  60.329  5.0  5.0         NaN         NaN
#
#                      i_oct_b1  i_oct_b2  num_particles_per_bunch  \
# beam  qx     qy
# lhcb1 62.305 60.309      60.0      60.0             1.400000e+11
#              60.310      60.0      60.0             1.400000e+11
#              60.311      60.0      60.0             1.400000e+11
#              60.312      60.0      60.0             1.400000e+11
#              60.313      60.0      60.0             1.400000e+11
# ...                       ...       ...                      ...
#       62.323 60.328      60.0      60.0             1.400000e+11
#              60.329      60.0      60.0             1.400000e+11
#       62.324 60.328      60.0      60.0             1.400000e+11
#              60.329      60.0      60.0             1.400000e+11
#       62.325 60.329      60.0      60.0             1.400000e+11
#
#                      crossing_angle
# beam  qx     qy
# lhcb1 62.305 60.309           250.0
#              60.310           250.0
#              60.311           250.0
#              60.312           250.0
#              60.313           250.0
# ...                             ...
#       62.323 60.328           250.0
#              60.329           250.0
#       62.324 60.328           250.0
#              60.329           250.0
#       62.325 60.329           250.0
#
# [231 rows x 12 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.309   3.862     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310   4.207   4.621     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311   4.207   4.345   5.448     NaN     NaN     NaN     NaN     NaN
# 60.312   3.931   5.379   5.793   5.931     NaN     NaN     NaN     NaN
# 60.313   4.690   5.586   5.724   5.655   6.069     NaN     NaN     NaN
# 60.314   5.379   5.586   5.862   5.655   5.379   4.966     NaN     NaN
# 60.315   4.207   5.862   6.207   5.931   5.310   5.724   4.897     NaN
# 60.316   4.828   5.724   5.724   5.448   5.379   5.586   5.862   6.483
# 60.317   5.517   6.069   5.931   5.379   5.172   5.379   5.724   6.414
# 60.318   5.517   5.931   5.655   5.448   5.448   5.310   5.586   5.586
# 60.319   5.448   5.931   5.931   5.448   5.448   5.724   6.069   6.483
# 60.320   4.276   5.931   5.724   5.448   5.655   5.655   5.586   6.138
# 60.321   5.517   5.517   5.862   5.172   5.586   5.724   6.138   6.069
# 60.322   5.172   5.310   5.172   5.241   5.586   5.310   5.172   6.276
# 60.323   5.172   5.172   5.517   5.517   5.517   5.034   5.586   5.034
# 60.324   4.897   4.759   5.103   5.379   5.172   5.034   5.034   5.448
# 60.325   4.621   4.897   4.897   4.759   4.759   4.897   4.897   5.172
# 60.326   4.690   4.621   4.621   4.621   4.621   4.276   4.483   4.690
# 60.327   4.345   4.345   4.276   4.276   4.621   4.276   4.414   4.552
# 60.328   4.000   4.138   4.414   4.276   3.862   3.862   4.069   3.931
# 60.329   3.724   3.793   3.586   3.586   3.517   3.655   3.517   3.724
#
# qx      62.313  62.314  ...  62.316  62.317  62.318  62.319  62.320  62.321  \
# qy                      ...
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317   6.897     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.318   7.310   7.034  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.319   7.103   7.310  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.320   6.897   7.310  ...   6.828     NaN     NaN     NaN     NaN     NaN
# 60.321   7.103   6.759  ...   6.897   6.897     NaN     NaN     NaN     NaN
# 60.322   6.552   6.690  ...   6.345   6.552   6.690     NaN     NaN     NaN
# 60.323   5.586   5.724  ...   6.207   6.345   6.414   6.069     NaN     NaN
# 60.324   5.655   5.448  ...   5.862   5.724   5.931   5.793   5.724     NaN
# 60.325   5.103   5.310  ...   5.172   5.379   5.448   5.448   5.517   5.655
# 60.326   4.828   4.828  ...   4.828   4.966   5.034   5.241   5.241   5.379
# 60.327   4.621   4.552  ...   4.621   4.759   4.690   4.690   4.621   4.897
# 60.328   4.138   4.207  ...   4.414   4.276   4.276   4.207   4.483   4.414
# 60.329   3.655   3.586  ...   3.793   3.862   3.931   4.000   3.793   4.000
#
# qx      62.322  62.323  62.324  62.325
# qy
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     NaN     NaN     NaN     NaN
# 60.324     NaN     NaN     NaN     NaN
# 60.325     NaN     NaN     NaN     NaN
# 60.326   5.448     NaN     NaN     NaN
# 60.327   5.034   5.103     NaN     NaN
# 60.328   4.690   4.621   4.483     NaN
# 60.329   4.138   4.138   4.000   4.069
#
# [21 rows x 21 columns]

# %%
# Replace NaNs above the upper diagonal with 8
for qx in df_to_plot.columns:
    for qy in df_to_plot.index:
        if qy >= qx - 2 + 0.004:
            if pd.isna(df_to_plot.loc[qy, qx]):
                df_to_plot.loc[qy, qx] = 8

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    f'{STUDY_NAME}_{COLLIDER}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flathv",
    betx=0.18,
    bety=0.075,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=4.,
    vmax=8.0,
    CC = True,
)
# ! Verified
