# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# # change directory to 'master_study/analysis'
# os.chdir('master_study/analysis')

# Local imports
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %%
# Define study
STUDY_NAME = "new_tunescan_50cm_2024_agressive"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0223/config_final.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                                             name base collider  \
# beam  qx     qy     num_particles_per_bunch
# lhcb1 62.305 60.306 240000000.0                  base_collider
#              60.307 240000000.0                  base_collider
#              60.308 240000000.0                  base_collider
#              60.309 240000000.0                  base_collider
#              60.310 240000000.0                  base_collider
# ...                                                        ...
#       62.328 60.327 240000000.0                  base_collider
#              60.329 240000000.0                  base_collider
#       62.329 60.326 240000000.0                  base_collider
#              60.327 240000000.0                  base_collider
#              60.328 240000000.0                  base_collider
#
#                                              normalized amplitude in xy-plane  \
# beam  qx     qy     num_particles_per_bunch
# lhcb1 62.305 60.306 240000000.0                                         9.250
#              60.307 240000000.0                                         8.938
#              60.308 240000000.0                                         9.375
#              60.309 240000000.0                                        10.125
#              60.310 240000000.0                                         9.688
# ...                                                                       ...
#       62.328 60.327 240000000.0                                         4.000
#              60.329 240000000.0                                         4.000
#       62.329 60.326 240000000.0                                         4.000
#              60.327 240000000.0                                         4.000
#              60.328 240000000.0                                         4.000
#
#                                                  qx      qy   dqx   dqy  \
# beam  qx     qy     num_particles_per_bunch
# lhcb1 62.305 60.306 240000000.0              62.305  60.306  10.0  10.0
#              60.307 240000000.0              62.305  60.307  10.0  10.0
#              60.308 240000000.0              62.305  60.308  10.0  10.0
#              60.309 240000000.0              62.305  60.309  10.0  10.0
#              60.310 240000000.0              62.305  60.310  10.0  10.0
# ...                                             ...     ...   ...   ...
#       62.328 60.327 240000000.0              62.328  60.327  10.0  10.0
#              60.329 240000000.0              62.328  60.329  10.0  10.0
#       62.329 60.326 240000000.0              62.329  60.326  10.0  10.0
#              60.327 240000000.0              62.329  60.327  10.0  10.0
#              60.328 240000000.0              62.329  60.328  10.0  10.0
#
#                                              i_bunch_b1  i_bunch_b2  i_oct_b1  \
# beam  qx     qy     num_particles_per_bunch
# lhcb1 62.305 60.306 240000000.0                     NaN         NaN     100.0
#              60.307 240000000.0                     NaN         NaN     100.0
#              60.308 240000000.0                     NaN         NaN     100.0
#              60.309 240000000.0                     NaN         NaN     100.0
#              60.310 240000000.0                     NaN         NaN     100.0
# ...                                                 ...         ...       ...
#       62.328 60.327 240000000.0                     NaN         NaN     100.0
#              60.329 240000000.0                     NaN         NaN     100.0
#       62.329 60.326 240000000.0                     NaN         NaN     100.0
#              60.327 240000000.0                     NaN         NaN     100.0
#              60.328 240000000.0                     NaN         NaN     100.0
#
#                                              i_oct_b2  num_particles_per_bunch
# beam  qx     qy     num_particles_per_bunch
# lhcb1 62.305 60.306 240000000.0                 100.0              240000000.0
#              60.307 240000000.0                 100.0              240000000.0
#              60.308 240000000.0                 100.0              240000000.0
#              60.309 240000000.0                 100.0              240000000.0
#              60.310 240000000.0                 100.0              240000000.0
# ...                                               ...                      ...
#       62.328 60.327 240000000.0                 100.0              240000000.0
#              60.329 240000000.0                 100.0              240000000.0
#       62.329 60.326 240000000.0                 100.0              240000000.0
#              60.327 240000000.0                 100.0              240000000.0
#              60.328 240000000.0                 100.0              240000000.0
#
# [368 rows x 11 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.305     NaN   9.812   9.250   9.688     NaN     NaN     NaN     NaN
# 60.306   9.250     NaN  10.750  10.312   8.938     NaN     NaN     NaN
# 60.307   8.938   9.562     NaN  10.000   9.625   8.438     NaN     NaN
# 60.308   9.375   9.625   9.875     NaN   8.688   9.125  10.312     NaN
# 60.309  10.125   9.562   9.938   9.250     NaN   9.625  10.188   9.750
# 60.310   9.688   9.250   9.000   9.625   9.875     NaN  11.000  11.000
# 60.311  10.188   9.312   9.375   8.375  10.188   9.438     NaN  11.062
# 60.312   9.125   9.875   9.438   7.938   9.688  10.875  11.312     NaN
# 60.313   9.125   8.562   9.812   8.875  10.750  10.625  10.938   9.688
# 60.314   9.625   9.625   9.438   9.438   8.625  10.062   9.625   9.625
# 60.315   9.375   9.250   9.438   9.375  10.188  10.312   9.250  10.375
# 60.316  10.000   9.125   9.312   9.438   9.500   9.500  10.188   9.750
# 60.317   9.688   9.250   8.688   9.312   9.062   9.562  10.562  10.562
# 60.318   9.750   9.750   9.500   8.688  10.000  10.125  10.312  10.688
# 60.319   9.625   8.938   9.500   9.625   8.875   9.188  10.188  10.062
# 60.320   8.750   8.375   8.688   9.000   8.875   8.750   9.062   9.375
# 60.321   8.125   7.500   9.062   9.000   8.500   9.438   9.125   9.375
# 60.322   7.625   8.125   7.750   8.062   7.375   8.375   8.062   8.562
# 60.323   7.500   7.375   7.438   7.688   7.250   7.938   7.688   7.438
# 60.324   6.625   7.125   7.250   7.000   7.000   6.688   7.188   7.188
# 60.325   6.188   6.500   6.438   6.000   6.438   6.312   6.312   7.062
# 60.326   6.188   6.562   6.125   5.875   5.750   6.312   5.812   5.750
# 60.327   6.125   5.938   6.188   6.062   5.812   5.812   5.875   5.562
# 60.328   6.562   6.375   5.625   5.875   6.125   5.562   5.688   6.000
# 60.329   5.938   5.812   6.000   5.875   5.125   5.750   5.500   4.562
#
# qx      62.313  62.314  ...  62.320  62.321  62.322  62.323  62.324  62.325  \
# qy                      ...
# 60.305     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310  11.250     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311  10.312  10.750  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312   9.812  11.062  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN  11.000  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314  10.500     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315  10.688  11.875  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316  10.312  11.125  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317  10.750  10.688  ...   9.688     NaN     NaN     NaN     NaN     NaN
# 60.318  10.750  10.500  ...  10.250   9.250     NaN     NaN     NaN     NaN
# 60.319  10.062  10.625  ...  10.375   9.375   8.562     NaN     NaN     NaN
# 60.320   9.438   9.375  ...     NaN  10.125   8.875   7.875     NaN     NaN
# 60.321   9.500   9.312  ...  10.312     NaN   9.375   8.188   6.938     NaN
# 60.322   8.938   8.625  ...   9.688   9.625     NaN   8.812   7.312   6.125
# 60.323   7.688   8.438  ...   8.438   8.938   8.812     NaN   7.875   6.188
# 60.324   7.062   6.625  ...   7.875   7.875   7.688   8.188     NaN   6.812
# 60.325   6.312   6.375  ...   6.500   6.875   6.500   7.062   7.250     NaN
# 60.326   6.312   6.000  ...   6.062   5.938   5.938   6.062   6.062   5.938
# 60.327   5.688   5.875  ...   5.312   5.312   5.375   5.125   5.062   5.000
# 60.328   5.625   5.500  ...   5.062   4.562   4.500   4.562   4.125   4.000
# 60.329   5.250   4.688  ...   4.250   4.438   4.062   4.000   4.000   4.000
#
# qx      62.326  62.327  62.328  62.329
# qy
# 60.305     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323   5.312     NaN     NaN     NaN
# 60.324   5.438   4.125     NaN     NaN
# 60.325   5.500   4.250     4.0     NaN
# 60.326     NaN   4.312     4.0     4.0
# 60.327   4.938     NaN     4.0     4.0
# 60.328   4.000   4.062     NaN     4.0
# 60.329   4.000   4.000     4.0     NaN
#
# [25 rows x 25 columns]

# %%
# Interpolate to fill internal missing values (do not extrapolate)
df_to_plot = df_to_plot.interpolate(method='slinear', limit = 1)

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.5,
    bety=0.5,
    Nb = True,
    green_contour = 2,
    extended_diagonal=True,
    #small_ext_diagonal=True,
    vmin = 4,
    vmax = 15.,
    smooth_symmetry = True,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)
