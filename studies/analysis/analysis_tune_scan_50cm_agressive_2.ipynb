# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# # change directory to 'master_study/analysis'
# os.chdir('master_study/analysis')

# Local imports
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %%
# Define study
STUDY_NAME = "tunescan_50cm_2024_agressive_2"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0223/config_final.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.306      base_collider                            10.625
#              60.307      base_collider                            10.375
#              60.308      base_collider                            11.688
#              60.309      base_collider                            10.250
#              60.310      base_collider                            12.750
# ...                                ...                               ...
#       62.328 60.327      base_collider                             4.000
#              60.329      base_collider                             4.000
#       62.329 60.326      base_collider                             4.000
#              60.327      base_collider                             4.000
#              60.328      base_collider                             4.000
#
#                          qx      qy   dqx   dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.306  62.305  60.306  10.0  10.0         NaN         NaN
#              60.307  62.305  60.307  10.0  10.0         NaN         NaN
#              60.308  62.305  60.308  10.0  10.0         NaN         NaN
#              60.309  62.305  60.309  10.0  10.0         NaN         NaN
#              60.310  62.305  60.310  10.0  10.0         NaN         NaN
# ...                     ...     ...   ...   ...         ...         ...
#       62.328 60.327  62.328  60.327  10.0  10.0         NaN         NaN
#              60.329  62.328  60.329  10.0  10.0         NaN         NaN
#       62.329 60.326  62.329  60.326  10.0  10.0         NaN         NaN
#              60.327  62.329  60.327  10.0  10.0         NaN         NaN
#              60.328  62.329  60.328  10.0  10.0         NaN         NaN
#
#                      i_oct_b1  i_oct_b2  num_particles_per_bunch  \
# beam  qx     qy
# lhcb1 62.305 60.306     100.0     100.0              180000000.0
#              60.307     100.0     100.0              180000000.0
#              60.308     100.0     100.0              180000000.0
#              60.309     100.0     100.0              180000000.0
#              60.310     100.0     100.0              180000000.0
# ...                       ...       ...                      ...
#       62.328 60.327     100.0     100.0              180000000.0
#              60.329     100.0     100.0              180000000.0
#       62.329 60.326     100.0     100.0              180000000.0
#              60.327     100.0     100.0              180000000.0
#              60.328     100.0     100.0              180000000.0
#
#                      crossing_angle
# beam  qx     qy
# lhcb1 62.305 60.306           130.0
#              60.307           130.0
#              60.308           130.0
#              60.309           130.0
#              60.310           130.0
# ...                             ...
#       62.328 60.327           130.0
#              60.329           130.0
#       62.329 60.326           130.0
#              60.327           130.0
#              60.328           130.0
#
# [368 rows x 12 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.305     NaN  11.875  11.062  11.062     NaN     NaN     NaN     NaN
# 60.306  10.625     NaN  10.000  10.500   9.938     NaN     NaN     NaN
# 60.307  10.375   9.812     NaN  11.625  12.062  11.438     NaN     NaN
# 60.308  11.688  11.875   9.375     NaN  10.500  11.125  11.812     NaN
# 60.309  10.250   8.375   9.500  10.312     NaN  12.250  11.188  10.438
# 60.310  12.750   9.375  11.125   9.938  11.562     NaN  12.188  11.938
# 60.311  10.500  11.625  10.375  12.625  12.062  11.188     NaN  12.000
# 60.312  10.875  10.500  11.062   9.250  10.500  12.750  11.250     NaN
# 60.313  11.625  10.438   9.562  10.062   9.688  13.125  11.875  11.625
# 60.314  10.312  10.875   9.875  11.625  10.375  12.500  11.688  12.062
# 60.315  10.250  11.250  10.438  12.062  10.500  11.625  11.688  11.812
# 60.316  11.438  11.062  10.188  10.062  10.938  11.312  12.125  10.875
# 60.317  10.938  10.750  12.000   9.812  11.312  10.312  11.375  11.312
# 60.318   9.875  10.812  10.062   9.250  10.625  11.250   9.938  10.500
# 60.319   8.938   9.688   9.750  10.375  10.250   9.375  11.062  10.938
# 60.320   9.500  10.062   9.562   8.250   8.375  10.188   9.500  10.312
# 60.321   9.438   9.188   9.438  10.188   8.625   9.062  10.938  10.688
# 60.322   8.688   9.125   8.625   8.312   8.125   9.375   8.812  10.250
# 60.323   7.688   8.312   8.000   8.188   7.750   8.500   8.562   8.875
# 60.324   7.625   7.562   7.000   7.312   7.312   7.875   8.000   8.125
# 60.325   6.125   7.375   6.688   6.688   6.750   7.062   7.062   7.375
# 60.326   6.938   6.188   6.562   6.000   6.250   6.500   6.250   6.375
# 60.327   6.500   6.688   6.750   6.438   6.875   6.375   6.875   5.750
# 60.328   6.562   7.000   6.062   6.625   6.375   6.000   6.312   5.875
# 60.329   6.312   6.500   6.562   6.312   5.750   6.000   5.500   5.562
#
# qx      62.313  62.314  ...  62.320  62.321  62.322  62.323  62.324  62.325  \
# qy                      ...
# 60.305     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310  11.062     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311  10.625  11.125  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312  11.500  11.438  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN  11.188  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314  11.750     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315  10.938  11.625  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316  11.562  11.375  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317  11.062  13.062  ...  10.750     NaN     NaN     NaN     NaN     NaN
# 60.318   9.875  11.625  ...  11.500   9.875     NaN     NaN     NaN     NaN
# 60.319  10.812  12.250  ...  12.625  10.812   9.438     NaN     NaN     NaN
# 60.320  11.188  11.312  ...     NaN  11.375  10.000   8.812     NaN     NaN
# 60.321  10.438   9.250  ...  11.125     NaN  11.375   9.188   8.062     NaN
# 60.322   9.938   9.312  ...  10.812  10.625     NaN  10.312   8.062   6.875
# 60.323   8.438   9.688  ...   9.688   9.875   9.625     NaN   9.250   7.375
# 60.324   8.250   8.125  ...   8.500   8.375   8.938   9.000     NaN   8.188
# 60.325   7.000   7.250  ...   7.750   7.688   7.625   7.812   8.000     NaN
# 60.326   6.875   6.188  ...   6.750   6.625   6.750   6.562   6.750   6.812
# 60.327   6.312   5.625  ...   6.000   5.812   5.688   5.750   5.625   5.500
# 60.328   6.188   6.125  ...   4.750   5.250   4.938   4.812   4.812   4.438
# 60.329   5.688   5.125  ...   5.062   4.812   5.000   4.062   4.062   4.000
#
# qx      62.326  62.327  62.328  62.329
# qy
# 60.305     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323   5.875     NaN     NaN     NaN
# 60.324   6.125   4.812     NaN     NaN
# 60.325   6.625   4.938     4.0     NaN
# 60.326     NaN   5.125     4.0     4.0
# 60.327   5.438     NaN     4.0     4.0
# 60.328   4.500   4.062     NaN     4.0
# 60.329   4.000   4.000     4.0     NaN
#
# [25 rows x 25 columns]

# %%
# Interpolate to fill internal missing values (do not extrapolate)
df_to_plot = df_to_plot.interpolate(method='slinear', limit = 1)

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.5,
    bety=0.5,
    Nb = True,
    green_contour = 2,
    extended_diagonal=True,
    #small_ext_diagonal=True,
    vmin = 4,
    vmax = 15.,
    smooth_symmetry = True,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)
