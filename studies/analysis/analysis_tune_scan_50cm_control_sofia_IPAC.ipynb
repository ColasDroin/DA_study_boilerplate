# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# # change directory to 'master_study/analysis'
# os.chdir('master_study/analysis')

# Local imports
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %%
# Define study
STUDY_NAME = "tunescan_50cm_control_sofia_IPAC"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0123/config_final.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.306      base_collider                             7.625
#              60.307      base_collider                             7.250
#              60.308      base_collider                             7.562
#              60.309      base_collider                             7.562
#              60.310      base_collider                             6.812
# ...                                ...                               ...
#       62.328 60.327      base_collider                             4.000
#              60.329      base_collider                             4.000
#       62.329 60.326      base_collider                             4.000
#              60.327      base_collider                             4.000
#              60.328      base_collider                             4.000
#
#                          qx      qy   dqx   dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.306  62.305  60.306  10.0  10.0         NaN         NaN
#              60.307  62.305  60.307  10.0  10.0         NaN         NaN
#              60.308  62.305  60.308  10.0  10.0         NaN         NaN
#              60.309  62.305  60.309  10.0  10.0         NaN         NaN
#              60.310  62.305  60.310  10.0  10.0         NaN         NaN
# ...                     ...     ...   ...   ...         ...         ...
#       62.328 60.327  62.328  60.327  10.0  10.0         NaN         NaN
#              60.329  62.328  60.329  10.0  10.0         NaN         NaN
#       62.329 60.326  62.329  60.326  10.0  10.0         NaN         NaN
#              60.327  62.329  60.327  10.0  10.0         NaN         NaN
#              60.328  62.329  60.328  10.0  10.0         NaN         NaN
#
#                      i_oct_b1  i_oct_b2  num_particles_per_bunch  \
# beam  qx     qy
# lhcb1 62.305 60.306     250.0     250.0              180000000.0
#              60.307     250.0     250.0              180000000.0
#              60.308     250.0     250.0              180000000.0
#              60.309     250.0     250.0              180000000.0
#              60.310     250.0     250.0              180000000.0
# ...                       ...       ...                      ...
#       62.328 60.327     250.0     250.0              180000000.0
#              60.329     250.0     250.0              180000000.0
#       62.329 60.326     250.0     250.0              180000000.0
#              60.327     250.0     250.0              180000000.0
#              60.328     250.0     250.0              180000000.0
#
#                      crossing_angle
# beam  qx     qy
# lhcb1 62.305 60.306            70.0
#              60.307            70.0
#              60.308            70.0
#              60.309            70.0
#              60.310            70.0
# ...                             ...
#       62.328 60.327            70.0
#              60.329            70.0
#       62.329 60.326            70.0
#              60.327            70.0
#              60.328            70.0
#
# [369 rows x 12 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.305     NaN   7.938   7.188   7.312     NaN     NaN     NaN     NaN
# 60.306   7.625     NaN   7.062   8.062   6.625     NaN     NaN     NaN
# 60.307   7.250   8.250     NaN   6.250   7.000   7.250     NaN     NaN
# 60.308   7.562   7.812   6.500     NaN   6.500   6.812   7.375     NaN
# 60.309   7.562   7.875   7.562   7.062     NaN   7.875   7.312   7.688
# 60.310   6.812   7.500   7.000   7.250   7.562     NaN   9.500   6.688
# 60.311   5.688   7.188   6.625   7.438   8.062   7.250     NaN   9.188
# 60.312   7.750   7.312   6.938   8.250   7.875   9.188   8.750     NaN
# 60.313   6.688   8.188   6.812   8.250   7.500   7.688   9.625   8.875
# 60.314   7.562   6.875   6.750   7.812   8.188   9.500   9.125   8.875
# 60.315   7.125   7.625   7.688   8.188   8.688   8.625   9.125   9.062
# 60.316   8.250   7.750   7.938   8.250   8.375   9.125   9.062   9.000
# 60.317   7.438   7.375   7.562   7.938   8.438   8.375   8.312   8.250
# 60.318   6.312   7.750   7.250   8.312   8.562   7.688   8.438   8.375
# 60.319   7.125   7.312   6.812   7.375   7.250   7.250   9.125   7.750
# 60.320   6.250   6.438   6.438   6.562   7.375   8.188   7.938   7.500
# 60.321   6.062   6.188   7.062   7.312   7.688   7.500   7.562   8.125
# 60.322   6.312   6.188   6.312   6.562   6.875   6.375   6.750   6.812
# 60.323   5.750   5.688   6.125   5.875   6.125   6.438   6.500   6.562
# 60.324   5.375   5.812   5.750   6.312   5.625   5.688   6.312   6.188
# 60.325   5.375   5.188   4.875   5.000   5.625   5.375   5.750   5.625
# 60.326   4.625   4.375   4.688   4.625   4.875   4.875   4.625   5.125
# 60.327   4.062   4.000   4.000   4.000   4.000   4.062   4.062   4.125
# 60.328   4.000   4.062   4.000   4.000   4.000   4.062   4.000   4.000
# 60.329   4.125   4.000   4.000   4.000   4.000   4.000   4.000   4.000
#
# qx      62.313  62.314  ...  62.320  62.321  62.322  62.323  62.324  62.325  \
# qy                      ...
# 60.305     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310   8.750     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311   9.125   8.312  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312   8.438   8.000  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN   8.562  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314   9.438     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315   8.875   9.625  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316   8.812   9.125  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317   8.562   9.312  ...   9.250     NaN     NaN     NaN     NaN     NaN
# 60.318   9.062   9.375  ...   9.625   8.938     NaN     NaN     NaN     NaN
# 60.319   7.812   7.938  ...  10.188   9.438   8.562     NaN     NaN     NaN
# 60.320   8.562   8.375  ...     NaN   9.688   8.375   7.500     NaN     NaN
# 60.321   7.312   8.312  ...   9.625     NaN   9.000   8.125   7.312     NaN
# 60.322   7.750   7.375  ...   9.000   9.188     NaN   8.812   7.688   6.188
# 60.323   7.062   7.375  ...   8.125   8.562   8.938     NaN   8.125   6.875
# 60.324   6.750   6.562  ...   7.375   7.250   7.312   7.688     NaN   7.562
# 60.325   6.062   6.062  ...   6.250   6.438   6.312   6.625   7.250     NaN
# 60.326   4.688   5.188  ...   5.500   5.500   5.688   5.438   5.188   6.250
# 60.327   4.438   4.062  ...   4.750   4.250   4.688   4.562   4.500   4.312
# 60.328   4.000   4.000  ...   4.000   4.000   4.000   4.000   4.000   4.000
# 60.329   4.000   4.000  ...   4.000   4.000   4.000   4.000   4.000   4.000
#
# qx      62.326  62.327  62.328  62.329
# qy
# 60.305     NaN     NaN     NaN     NaN
# 60.306     NaN     NaN     NaN     NaN
# 60.307     NaN     NaN     NaN     NaN
# 60.308     NaN     NaN     NaN     NaN
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323   5.062     NaN     NaN     NaN
# 60.324   5.938   4.125     NaN     NaN
# 60.325   6.375   4.250     4.0     NaN
# 60.326     NaN   4.938     4.0     4.0
# 60.327   5.375     NaN     4.0     4.0
# 60.328   4.062   4.000     NaN     4.0
# 60.329   4.000   4.000     4.0     NaN
#
# [25 rows x 25 columns]

# %%
# Interpolate to fill internal missing values (do not extrapolate)
df_to_plot = df_to_plot.interpolate(method='slinear', limit = 1)

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.5,
    bety=0.5,
    Nb = True,
    green_contour = 2,
    extended_diagonal=True,
    #small_ext_diagonal=True,
    vmin = 3,
    vmax = 9.,
    smooth_symmetry = True,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)
